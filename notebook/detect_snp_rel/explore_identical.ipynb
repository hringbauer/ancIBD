# %%
import qgrid
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import socket as socket
import os as os
import sys as sys
import multiprocessing as mp
import itertools as it
import h5py

### hapROH imports
#sys.path.insert(0,"/n/groups/reich/hringbauer/git/HAPSBURG/package/")  # hack to get development package first in path
sys.path.insert(0,"/n/groups/reich/hringbauer/git/hapBLOCK/package/hapBLOCK/IO/")  # hack to get development package first in path
from h5_load import get_coverage,get_genos_pairs,get_idx_iid,get_markers_good

socket_name = socket.gethostname()
print(socket_name)

if socket_name.startswith("compute-"):
    print("HSM O2 Computational partition detected.")
    path = "/n/groups/reich/hringbauer/git/hapBLOCK/"  # The Path on Harvard Cluster
else:
    raise RuntimeWarning("No compatible machine. Check!!")

os.chdir(path)  # Set the right Path (in line with Atom default)
# Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns

print(os.getcwd())
print(f"CPU Count: {mp.cpu_count()}")

sys.path.insert(0, path)
# Out:
# compute-a-17-86.o2.rc.hms.harvard.edu
# HSM O2 Computational partition detected.
# /n/groups/reich/hringbauer/git/hapBLOCK
# CPU Count: 32

# %%
df = pd.read_csv("./output/relatives_snp/opp_homos_ch3_processed_unique_novel.tsv", sep="\t")
df_all = pd.read_csv("./output/relatives_snp/opp_homos_ch3_processed_all.tsv", sep="\t")
df_meta = pd.read_csv("/n/groups/reich/hringbauer/Data/v43.4.anno.csv", sep=",")  # Load Meta File

# %%
#df_iosif = df[df["study1"].str.contains("Iosif") | df["study2"].str.contains("Iosif")]
df_iosif = df[df["study1"].str.contains("Anthony") | df["study2"].str.contains("Anthony")]

# %%
df["study1"].value_counts()

# %%
df_iosif

# %%
df_iosif.to_csv("./output/dumpster/alissa_duplicates.tsv", sep="\t", index=False)

# %% [markdown]
# ### Age Seperation

# %%
df_all["delta_age"] = np.abs(df_all["age1"]-df_all["age2"])

# %%
df_all.sort_values(by="delta_age", ascending=False)[:5]
# Out:
#                 iid1    iid2  opp_homo_rate_ch3  gt_match_rate_ch3  \
# 1590  KPT002_petrous  UKY001                0.0           1.000000
# 1457          I18532  I18846                0.0           0.830194
# 1531          I20475  I20474                0.0           0.999938
# 1530          I20477  I20464                0.0           0.999924
# 1386          I16762  R19.SG                0.0           0.999468
#
#       frac_snps_good_ch3 Master ID1 Master ID2  n_cov_snp1  n_cov_snp2  \
# 1590            0.804974     KPT002     UKY001      662023      672228
# 1457            0.784950     I18532     I18846      588675      597803
# 1531            0.796064     I20475     I20474      500775      655268
# 1530            0.960393     I20477     I20464      895809     1005124
# 1386            0.873712     I16762        R19      729175      498407
#
#         age1     age2                                       study1  \
# 1590  3931.0  13904.0                                   YuCell2020
# 1457   500.0   4285.0                      Unpublished / Unclaimed
# 1531  2800.0      0.0                      Unpublished / Unclaimed
# 1530  2800.0      0.0                      Unpublished / Unclaimed
# 1386  4450.0   7233.0  Unpublished (Alissa broad Italian transect)
#
#                           study2  \
# 1590                  YuCell2020
# 1457     Unpublished / Unclaimed
# 1531     Unpublished / Unclaimed
# 1530     Unpublished / Unclaimed
# 1386  AntonioGaoMootsScience2019
#
#                                                 clst1  \
# 1590                          Russia_Siberia_Lena_EBA
# 1457                            Hungary_Late_Medieval
# 1531  Brazil_LateHolocene_PrePotteryANDItararePottery
# 1530  Brazil_LateHolocene_PrePotteryANDItararePottery
# 1386                            Italy_South_C_Laterza
#
#                                                 clst2  \
# 1590                                Russia_Siberia_UP
# 1457                   Brazil_LateHolocene_PrePottery
# 1531  Brazil_LateHolocene_PrePotteryANDItararePottery
# 1530  Brazil_LateHolocene_PrePotteryANDItararePottery
# 1386                                       Italy_N.SG
#
#                           family1                      family2  \
# 1590  n/a (no relatives detected)  n/a (no relatives detected)
# 1457  n/a (no relatives detected)  n/a (no relatives detected)
# 1531  n/a (no relatives detected)  n/a (no relatives detected)
# 1530  n/a (no relatives detected)  n/a (no relatives detected)
# 1386  n/a (no relatives detected)  n/a (no relatives detected)
#
#            relatedness  delta_age
# 1590         Identical     9973.0
# 1457  Parent Offspring     3785.0
# 1531         Identical     2800.0
# 1530         Identical     2800.0
# 1386         Identical     2783.0

# %% [markdown]
# # Area 51

# %%
df_meta[df_meta["study"].str.contains("YuCell2020")].sort_values(by="age")
# Out:
#                   iid Master ID        lat         lon      age  region  \
# 13832          KPT006    KPT006  53.044528  105.510583   3614.0  Russia
# 13580          KAG002    KAG002  53.949444  105.890194   3748.0  Russia
# 8041           KPT001    KPT001  53.044528  105.510583   3759.0  Russia
# 8706           KPT004    KPT004  53.044528  105.510583   3773.0  Russia
# 15927    KPT002_tooth    KPT002  53.044528  105.510583   3931.0  Russia
# 9582   KPT002_petrous    KPT002  53.044528  105.510583   3931.0  Russia
# 8215           KPT003    KPT003  53.044528  105.510583   3945.0  Russia
# 8886           ZPL001    ZPL001  54.386333  105.173250   3951.0  Russia
# 15272          KPT005    KPT005  53.044528  105.510583   4034.0  Russia
# 12271          ZPL002    ZPL002  54.386333  105.173250   4168.0  Russia
# 8276           GLZ002    GLZ002  52.279056  104.251778   4430.0  Russia
# 12039          GLZ003    GLZ003  52.279056  104.251778   4478.0  Russia
# 8952           GLZ001    GLZ001  52.279056  104.251778   4556.0  Russia
# 5714           STB001    STB001  54.800000  105.133333   4604.0  Russia
# 7088           BZK002    BZK002  55.990333   92.851000   4708.0  Russia
# 7400           STB002    STB002  53.150000  106.050000   6587.0  Russia
# 9023           KAG001    KAG001  53.949444  105.890194   6856.0  Russia
# 7434           IUO001    IUO001  54.870722  106.255056   6905.0  Russia
# 16295          ANG001    ANG001  52.214500  104.348667   7274.0  Russia
# 9431           UKY001    UKY001  50.534142  106.274289  13904.0  Russia
#
#             study                                        clst  mean_cov  \
# 13832  YuCell2020                     Russia_Siberia_Lena_EBA  0.142095
# 13580  YuCell2020                     Russia_Siberia_Lena_EBA  0.161472
# 8041   YuCell2020                     Russia_Siberia_Lena_EBA  0.632935
# 8706   YuCell2020                     Russia_Siberia_Lena_EBA  0.603240
# 15927  YuCell2020  Russia_Siberia_Lena_EBA_dup.KPT002_petrous  0.038644
# 9582   YuCell2020                     Russia_Siberia_Lena_EBA  0.551686
# 8215   YuCell2020                     Russia_Siberia_Lena_EBA  0.625907
# 8886   YuCell2020                     Russia_Siberia_Lena_EBA  0.593087
# 15272  YuCell2020                   Russia_Siberia_Lena_EBA_o  0.061589
# 12271  YuCell2020                     Russia_Siberia_Lena_EBA  0.299357
# 8276   YuCell2020                  Russia_Siberia_Irkutsk_EBA  0.622935
# 12039  YuCell2020                  Russia_Siberia_Irkutsk_EBA  0.324628
# 8952   YuCell2020                  Russia_Siberia_Irkutsk_EBA  0.589782
# 5714   YuCell2020                     Russia_Siberia_Lena_EBA  0.721431
# 7088   YuCell2020                  Russia_Siberia_Tenisei_EBA  0.667767
# 7400   YuCell2020                     Russia_Siberia_Lena_EBA  0.656360
# 9023   YuCell2020                      Russia_Siberia_Lena_EN  0.584719
# 7434   YuCell2020                      Russia_Siberia_Lena_EN  0.655046
# 16295  YuCell2020                    Russia_Siberia_Angara_EN  0.028125
# 9431   YuCell2020                           Russia_Siberia_UP  0.560190
#
#        n_cov_snp avg_cov_snp  include_alt                       family
# 13832     170514    0.173143         True  n/a (no relatives detected)
# 13580     193766    0.202291         True  n/a (no relatives detected)
# 8041      759522    1.483799         True  n/a (no relatives detected)
# 8706      723888    1.865994         True  n/a (no relatives detected)
# 15927      46373    0.040061         True  n/a (no relatives detected)
# 9582      662023    1.338897         True  n/a (no relatives detected)
# 8215      751088    1.464448         True  n/a (no relatives detected)
# 8886      711704    1.240023         True  n/a (no relatives detected)
# 15272      73907    0.075135         True  n/a (no relatives detected)
# 12271     359229    0.387973         True  n/a (no relatives detected)
# 8276      747522    1.410246         True  n/a (no relatives detected)
# 12039     389554     0.42862         True  n/a (no relatives detected)
# 8952      707738    1.053972         True  n/a (no relatives detected)
# 5714      865717    1.944525         True  n/a (no relatives detected)
# 7088      801320    1.500193         True  n/a (no relatives detected)
# 7400      787632    1.567448         True  n/a (no relatives detected)
# 9023      701663    1.136537         True  n/a (no relatives detected)
# 7434      786055    1.412679         True  n/a (no relatives detected)
# 16295      33750    0.033435         True  n/a (no relatives detected)
# 9431      672228    1.378958         True  n/a (no relatives detected)
